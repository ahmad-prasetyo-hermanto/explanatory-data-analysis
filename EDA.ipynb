# %%
import pandas as pd

data = pd.read_csv('/content/sample_data/world_happiness_2015.csv')

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
# 158  Netherlands                   Western Europe               7
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
# 158            7.378         0.02799                   1.32944  1.28017
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143      NaN                            NaN
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
# 158                   0.89284  0.61576                        0.31814
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
# 158     0.47610            2.46570
#
# [159 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        159 non-null    object
#  1   Region                         159 non-null    object
#  2   Happiness Rank                 159 non-null    int64
#  3   Happiness Score                159 non-null    float64
#  4   Standard Error                 159 non-null    float64
#  5   Economy (GDP per Capita)       159 non-null    float64
#  6   Family                         159 non-null    float64
#  7   Health (Life Expectancy)       159 non-null    float64
#  8   Freedom                        157 non-null    float64
#  9   Trust (Government Corruption)  156 non-null    float64
#  10  Generosity                     159 non-null    float64
#  11  Dystopia Residual              159 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 15.0+ KB

# %%
data.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          2
# Trust (Government Corruption)    3
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      159.000000       159.000000      159.000000
# mean        79.037736         5.388327        0.047760
# std         45.970255         1.152374        0.017164
# min          1.000000         2.839000        0.018480
# 25%         39.500000         4.534000        0.037030
# 50%         79.000000         5.253000        0.043940
# 75%        118.500000         6.282000        0.052280
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                159.000000  159.000000                159.000000
# mean                   0.849177    0.992864                  0.631911
# std                    0.403667    0.272472                  0.247173
# min                    0.000000    0.000000                  0.000000
# 25%                    0.546035    0.858015                  0.439640
# 50%                    0.918510    1.032760                  0.697020
# 75%                    1.164410    1.217935                  0.812425
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  157.000000                     156.000000  159.000000
# mean     0.429115                       0.143103    0.238797
# std      0.150375                       0.119457    0.127696
# min      0.000000                       0.000000    0.000000
# 25%      0.328780                       0.061067    0.151285
# 50%      0.436260                       0.107220    0.216840
# 75%      0.550110                       0.180675    0.314745
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         159.000000
# mean            2.101283
# std             0.552561
# min             0.328580
# 25%             1.760090
# 50%             2.100170
# 75%             2.465505
# max             3.602140

# %%
data[['Country','Region']].describe()
# Out:
#             Country              Region
# count           159                 159
# unique          158                  10
# top     Netherlands  Sub-Saharan Africa
# freq              2                  40

# %%
# Mengatasi missing value
for column in data.columns:
    if data[column].dtype == 'object':
        # Jika kolom bertipe object, isi dengan mode
        data[column].fillna(data[column].mode()[0], inplace=True)
    else:
        # Jika kolom bertipe numerik, isi dengan mean
        data[column].fillna(data[column].mean(), inplace=True)
# Out:
# <ipython-input-10-324ae1348a0d>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mode()[0], inplace=True)
# <ipython-input-10-324ae1348a0d>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)

# %%
data.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        159 non-null    object
#  1   Region                         159 non-null    object
#  2   Happiness Rank                 159 non-null    int64
#  3   Happiness Score                159 non-null    float64
#  4   Standard Error                 159 non-null    float64
#  5   Economy (GDP per Capita)       159 non-null    float64
#  6   Family                         159 non-null    float64
#  7   Health (Life Expectancy)       159 non-null    float64
#  8   Freedom                        159 non-null    float64
#  9   Trust (Government Corruption)  159 non-null    float64
#  10  Generosity                     159 non-null    float64
#  11  Dystopia Residual              159 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 15.0+ KB

# %%
# Mengecek apakah ada duplicate di seluruh kolom
check_duplicate = data.duplicated().sum()

print(f"Jumlah data yang duplikat = {check_duplicate}")
# Out:
# Jumlah data yang duplikat = 1

# %%
# Handling duplicate
data = data.drop_duplicates()

# %%
# Mengecek duplicate setelah di-handle
handle_duplicate = data.duplicated().sum()

print(f"Jumlah data yang duplikat = {handle_duplicate}")
# Out:
# Jumlah data yang duplikat = 0
